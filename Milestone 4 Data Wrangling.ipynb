# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
url = 'https://www.worldometers.info/coronavirus/country/us/'
req = requests.get(url)
page = BeautifulSoup(req.content, 'html.parser')

table = page.find_all('table',id="usa_table_countries_today")[0]

df = pd.read_html(str(table), displayed_only=False)[0]
df
# Out:
#        #              USA State  Total Cases  New Cases  Total Deaths  \
# 0    NaN              USA Total    109339844        NaN     1182163.0
# 1    1.0             California     12503722        NaN      105570.0
# 2    2.0                  Texas      8889284        NaN       95298.0
# 3    3.0                Florida      7841223        NaN       91921.0
# 4    4.0               New York      7246689        NaN       78417.0
# ..   ...                    ...          ...        ...           ...
# 60  60.0        Federal Prisons        71485        NaN         324.0
# 61  61.0    Grand Princess Ship          122        NaN           7.0
# 62  62.0      Wuhan Repatriated            3        NaN           NaN
# 63  63.0  Diamond Princess Ship           46        NaN           NaN
# 64   NaN                 Total:    109339844        NaN     1182163.0
#
#     New Deaths  Total Recovered  Active Cases  Tot Cases/ 1M pop  \
# ...

# %%
# dropping unnecessary columns
df = df.drop(['#','Population','Source','Projections'], axis = 1)
df.head(5)
# Out:
#     USA State  Total Cases  New Cases  Total Deaths  New Deaths  \
# 0   USA Total    109339844        NaN     1182163.0         NaN
# 1  California     12503722        NaN      105570.0         NaN
# 2       Texas      8889284        NaN       95298.0         NaN
# 3     Florida      7841223        NaN       91921.0         NaN
# 4    New York      7246689        NaN       78417.0         NaN
#
#    Total Recovered  Active Cases  Tot Cases/ 1M pop  Deaths/ 1M pop  \
# 0      107274717.0      882964.0           330417.0          3572.0
# 1       12357464.0       40688.0           316452.0          2672.0
# 2        8767055.0       26931.0           306571.0          3287.0
# 3        7734061.0       15241.0           365086.0          4280.0
# 4        7154040.0       14232.0           372512.0          4031.0
#
#     Total Tests  Tests/ 1M pop
# 0  1.186432e+09      3585306.0
# 1  2.027994e+08      5132573.0
# 2  7.390438e+07      2548789.0
# 3  6.680009e+07      3110202.0
# ...

# %%
df.isnull().sum()
# Out:
# USA State             0
# Total Cases           0
# New Cases            65
# Total Deaths          2
# New Deaths           65
# Total Recovered      11
# Active Cases         11
# Tot Cases/ 1M pop    11
# Deaths/ 1M pop       11
# Total Tests           2
# Tests/ 1M pop        11
# dtype: int64

# %%
# Replacing NaN Values with 0
df3 = df_3.fillna(0)
# checking if there is any otherkind of null values is df_3
df3.isnull().sum()
# Out:
# USA State            0
# Total Cases          0
# New Cases            0
# Total Deaths         0
# New Deaths           0
# Total Recovered      0
# Active Cases         0
# Tot Cases/ 1M pop    0
# Deaths/ 1M pop       0
# Total Tests          0
# Tests/ 1M pop        0
# dtype: int64

# %%
# checking Duplicate value in dataframe
df3['USA State'].duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 60    False
# 61    False
# 62    False
# 63    False
# 64    False
# Name: USA State, Length: 65, dtype: bool

# %%
# Replacing column names
df3 = df3.rename(columns = {'Deaths/ 1M pop':'Deaths/ 1M','Tests/ 1M pop':'Tests/ 1M'})
df3.columns
# Out:
# Index(['USA State', 'Total Cases', 'New Cases', 'Total Deaths', 'New Deaths',
#        'Total Recovered', 'Active Cases', 'Tot Cases/ 1M pop', 'Deaths/ 1M',
#        'Total Tests', 'Tests/ 1M'],
#       dtype='object')
